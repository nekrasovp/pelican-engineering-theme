# %% [markdown]
# ## Static notebook presentation
#
# This repository-owned example includes committed outputs and inline math: $E = mc^2$.

# %%
message = 'static committed output'
# Out:
# committed stream output

# %%
error_state = 'already committed'
# Out:
# Traceback (most recent call last):
# ExampleError: committed traceback output

# %%
wide_matrix = 'committed dataframe output'
# Out:
# Wide static build matrix

# %%
png_state = 'committed raster output'
# Out:
# <one-pixel repository-owned PNG>

# %%
svg_state = 'committed vector output'
# Out:
# Static pipeline diagram

# %%
rich_state = 'trusted committed HTML'
# Out:
# Trusted committed HTML

# %%
figure_state = 'committed figure output'
# Out:
# Repository-owned figure and caption

# %%
plot_state = 'committed static container'
# Out:
# Static embedded-output container
